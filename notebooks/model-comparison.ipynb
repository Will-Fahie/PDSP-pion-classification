# %% [markdown]
# # Model Comparison
#
# ROC + efficiency-matched purity for: MLP (summary stats), CNN (dEdX only),
# Hybrid CNN+MLP, vs. the contemporary cut-based selector.

# %%
import os, pickle

if os.path.basename(os.getcwd()) == 'notebooks':
    os.chdir('..')

import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc


def load(path):
    with open(path, 'rb') as f:
        return pickle.load(f)


mlp    = load('results/mlp_summary.pkl')
cnn    = load('results/cnn_dEdX.pkl')
hybrid = load('results/hybrid_cnn_mlp.pkl')

for r in [mlp, cnn, hybrid]:
    print(r['model_name'])
    print(f"  AUC: {r['auc']:.3f}  |  Purity: {100*r['purity']:.1f}%  |  Efficiency: {100*r['efficiency']:.1f}%")

# %%
PION_LABEL = r'$\pi^{\pm}$'

pion_cuts = [
    lambda pfo: pfo['track_chi2/ndof_proton'] > 61.2,
    lambda pfo: pfo['track_length'] > 27.1,
    lambda pfo: pfo['track_score'] > 0.5,
    lambda pfo: 1.6 < pfo['dEdX_median'] < 2.8,
]

with open('prepared-data/test_tracks.pkl', 'rb') as f:
    test_pfos = pickle.load(f)

cut_labels = np.array([
    1 if PION_LABEL in pfo['particle'] and pfo['particle'] != r'$\pi^{\pm}$:2nd' else 0
    for pfo in test_pfos
])
cut_preds = np.array([1 if all(fn(pfo) for fn in pion_cuts) else 0 for pfo in test_pfos])

TP = int(((cut_preds == 1) & (cut_labels == 1)).sum())
FP = int(((cut_preds == 1) & (cut_labels == 0)).sum())
FN = int(((cut_preds == 0) & (cut_labels == 1)).sum())
TN = int(((cut_preds == 0) & (cut_labels == 0)).sum())

tpr_cut = TP / (TP + FN)
fpr_cut = FP / (FP + TN)
print('Cut-based operating point:')
print(f'  FPR = {fpr_cut:.4f}  ({100*fpr_cut:.2f}%)')
print(f'  TPR (efficiency) = {tpr_cut:.4f}  ({100*tpr_cut:.2f}%)')

# Hybrid efficiency at matched FPR (interpolated on the ROC)
fpr_h, tpr_h, _ = roc_curve(hybrid['labels'], hybrid['probs'])
tpr_hybrid = np.interp(fpr_cut, fpr_h, tpr_h)

print(f'\nHybrid at FPR = {fpr_cut:.4f}:')
print(f'  Efficiency = {tpr_hybrid:.4f}  ({100*tpr_hybrid:.2f}%)')
print(f'  Gain over cut-based: +{100*(tpr_hybrid - tpr_cut):.2f} pp')

# %%
fig, ax = plt.subplots(figsize=(8, 7), dpi=300)

for r, color, name in [(cnn, 'steelblue', 'CNN'),
                       (hybrid, 'crimson', 'CNN+MLP'),
                       (mlp, 'darkorange', 'MLP')]:
    fpr, tpr, _ = roc_curve(r['labels'], r['probs'])
    ax.plot(fpr, tpr, color=color, lw=2, label=f"{name} (AUC = {auc(fpr, tpr):.3f})")

    preds = (r['probs'] >= r['threshold']).astype(int)
    tp = int(((preds == 1) & (r['labels'] == 1)).sum())
    fp = int(((preds == 1) & (r['labels'] == 0)).sum())
    fn = int(((preds == 0) & (r['labels'] == 1)).sum())
    tn = int(((preds == 0) & (r['labels'] == 0)).sum())
    ax.scatter(fp / (fp + tn), tp / (tp + fn), color=color, marker='o', s=80, zorder=5)

ax.scatter(fpr_cut, tpr_cut, color='black', marker='o', s=80, zorder=6, label='Cut-based')
ax.plot([0, 1], [0, 1], 'k--', alpha=0.4, lw=1)
ax.set_xlabel('False positive rate', fontsize=15)
ax.set_ylabel('Efficiency', fontsize=15)
ax.legend(fontsize=14, framealpha=0.9)
ax.tick_params(labelsize=14)
ax.set_xlim([0, 1])
ax.set_ylim([0, 1])
ax.grid(True, linestyle='--', alpha=0.4)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.tight_layout()
plt.show()

# %%
# Match each model's threshold to the cut-based efficiency, then report purity.
CUT_EFF_TARGET = 0.542
FIXED_EFF = 54.2  # %


def thresh_at_eff(labels, probs, target, n=5000):
    best_t, best_d = 0.5, float('inf')
    for t in np.linspace(0.01, 0.99, n):
        preds = (probs >= t).astype(int)
        tp = int(((preds == 1) & (labels == 1)).sum())
        fn = int(((preds == 0) & (labels == 1)).sum())
        eff = tp / (tp + fn) if (tp + fn) else 0.0
        if abs(eff - target) < best_d:
            best_d, best_t = abs(eff - target), t
    return best_t


def purity_at(labels, probs, t):
    preds = (probs >= t).astype(int)
    tp = int(((preds == 1) & (labels == 1)).sum())
    fp = int(((preds == 1) & (labels == 0)).sum())
    if tp + fp == 0:
        return 0.0, 0.0
    p = tp / (tp + fp)
    return 100 * p, 100 * np.sqrt(p * (1 - p) / (tp + fp))


# Cut-based purity is fixed (computed in the topology-selection notebook)
rows = [('Cut-based', 51.3, 0.4, None)]
for r, label in zip([mlp, cnn, hybrid], ['MLP', 'CNN', 'Hybrid']):
    t = thresh_at_eff(r['labels'], r['probs'], CUT_EFF_TARGET)
    pur, dpur = purity_at(r['labels'], r['probs'], t)
    rows.append((label, pur, dpur, t))

col_labels = ['Model', 'Efficiency (%)', 'Purity (%)', 'Purity × Efficiency (%)', 'Threshold']
cell_text = [
    [name,
     f'{FIXED_EFF:.1f}',
     f'{pur:.1f} ± {dpur:.1f}',
     f'{pur * FIXED_EFF / 100:.2f}',
     f'{t:.3f}' if t is not None else '-']
    for name, pur, dpur, t in rows
]

fig, ax = plt.subplots(figsize=(13, 2.5), dpi=150)
ax.axis('off')
tbl = ax.table(cellText=cell_text, colLabels=col_labels, loc='center', cellLoc='center')
tbl.auto_set_font_size(False)
tbl.set_fontsize(13)
tbl.scale(1, 2.2)

for j in range(len(col_labels)):
    tbl[0, j].set_facecolor('#2c3e50')
    tbl[0, j].set_text_props(color='white', fontweight='bold')
for i in range(1, len(rows) + 1):
    bg = '#f5f5f5' if i % 2 == 0 else 'white'
    for j in range(len(col_labels)):
        tbl[i, j].set_facecolor(bg)

plt.tight_layout()
plt.show()
